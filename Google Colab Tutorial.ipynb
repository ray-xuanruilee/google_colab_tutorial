# %% [markdown]
# # Agenda:
#
# 1.   Changing Runtime Type. ***(Provision a GPU / TPU, useful for Deep Learning.)***
# 2.   Uploading Data to Google Colab.
# 3.   Markdown & Rich Text.
# 4.   Saving, Downloading & Sharing Google Colab File.
# 5.   Execute System Level Command from Google Colab.
# 6.   Google Colab Magic Commands.
# 7.   Execute External Python File.
# 8.   Utilizing GPU, TPU on Google Colab.

# %% [markdown]
# # 0. Google Colab Shortcuts
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Changing Runtime Type
#
# 1.   Select "Runtime".
# 2.   Click on "Runtime Type".
# 3.   **Under "Hardware Accelerator", pick "GPU" or "TPU".**
# 4.   "None" means you're selecting a CPU, by default.

# %% [markdown]
# # 2. Uploading Data to Google Colab
# 1.   Public Link
# 2.   Google Drive
# 3.   GitHub Link
# 4.   Local Drive

# %%
import numpy as np
import pandas as pd

# %%
# 1. Public Link

# !wget <insert url>

# To invoke any system level command, include a "!" in front to execute code using your system environment.

# %%
# Tip: You can list all files and directories with a "LS" command

# !ls
# Out:
# drive  sample_data

# %% [markdown]
# *   *Alternatively, you can click on the "File" icon on the left hand side to view all files within your Directory.*

# %%
# 2. Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# After you have mounted your Drive and granted necessary permissions, you can read the data within the Drive

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sample Datasets/titanic/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 3. GitHub Link

# !git clone <insert GitHuyb repo link 'https://github.com/parameters.git'>

# %% [markdown]
# *   **4. Local Drive:** Simply go to your left hand panel, click on the "Upload to Session Storage" icon.
# *   Note, your files will only persist within this session, so the next time you return in another session, this will disappear.

# %% [markdown]
# # 3. Markdown & Rich Text
# 1.   You can use # for Heading 1, or ## for Heading 2 and so on.
# 2.   # Heading 1.
# 3.   ### Heading 3.
# 4.   Bold with " ** ** ", **bold**.
# 5.   Italics with " * * ", *italics*.
# 6.   LaTex with 2 dollar signs *(see below)*.
# 7.   $x1 = \frac{-b + \sqrt({b^2 - 4ac})}{2a}$
# 8.   $$x1 = \frac{-b + \sqrt({b^2 - 4ac})}{2a}$$

# %% [markdown]
# # 4. Saving, Downloading & Sharing Google Colab File.
# 1.   "File" > "Save a Copy in Drive".
# 2.   "File" > "Save a Copy as GitHub Gist".
# 3.   "File" > "Save a Copy in GitHub".
# 4.   "file" > "Save" as a Local Copy.
# 5.   To **share**, click on the "Share" icon on the top right hand corner and share it with individual emails / groups *(with your selected permissions)*.

# %% [markdown]
# # 5. Execute System Level Command from Google Colab.
# 1.   Can be used to install packages.
# 2.   Can be used to check package versions.

# %%
# 1. Install Python Packages

# !pip install pgmpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 33.3 MB/s eta 0:00:00
# ...

# %%
# 2. Check Package Versions

# !python --version
# Out:
# Python 3.9.16

# %%
# 2. Check Package Versions

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
# Execute system level command with "!"

# !ls /bin # List all utilities that are part of /bin
# Out:
# '['				      mpiexec.openmpi
#  2to3-2.7			      mpif77
#  7z				      mpif77.openmpi
#  7za				      mpif90
#  7zr				      mpif90.openmpi
#  aclocal			      mpifort
#  aclocal-1.16			      mpifort.openmpi
#  acyclic			      mpirun
#  add-apt-repository		      mpirun.openmpi
#  addpart			      mtrace
#  addr2line			      mv
#  apropos			      mysql_config
#  apt				      namei
#  apt-add-repository		      nawk
#  apt-cache			      ncal
#  apt-cdrom			      nc-config
#  apt-config			      ncurses5-config
#  apt-extracttemplates		      ncurses6-config
#  apt-ftparchive			      ncursesw5-config
#  apt-get			      ncursesw6-config
#  apt-key			      neato
#  apt-mark			      neqn
#  apt-sortpkgs			      networkctl
#  ar				      newgrp
#  arch				      nice
#  as				      nisdomainname
#  asan_symbolize			      nl
#  asan_symbolize-10		      nm
#  assistant			      nns
#  autoconf			      nnsd
#  autoheader			      nnslog
#  autom4te			      nohup
#  automake			      nop
# ...

# %%
# Get current directory

# !pwd
# Out:
# /content

# %%
# Get Date

# !date
# Out:
# Wed 12 Apr 2023 03:36:58 AM UTC

# %% [markdown]
# # 6. Google Colab Magic Commands.
# 1.   Line Magic Command, With %%.
# 2.   Cell Magic Command, With %.

# %% [markdown]
# 1. Line Magic Commands.

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# Add "?" to display documentation from the %alias Line Magic Command

# %alias?

# %%
# %alias
# Out:
# Total number of aliases: 12
# [('cat', 'cat'),
#  ('cp', 'cp'),
#  ('ldir', 'ls -F -o --color %l | grep /$'),
#  ('lf', 'ls -F -o --color %l | grep ^-'),
#  ('lk', 'ls -F -o --color %l | grep ^l'),
#  ('ll', 'ls -F -o --color'),
#  ('ls', 'ls -F --color'),
#  ('lx', 'ls -F -o --color %l | grep ^-..x'),
#  ('mkdir', 'mkdir'),
#  ('mv', 'mv'),
#  ('rm', 'rm'),
#  ('rmdir', 'rmdir')]

# %%
# %history
# Out:
# import numpy as np
# import pandas as pd
# # 1. Public Link
#
# # !wget <insert url>
#
# # To invoke any system level command, include a "!" in front to execute code using your system environment.
# # Tip: You can list all files and directories with a "LS" command
#
# !ls
# # 2. Google Drive
# from google.colab import drive
# drive.mount('/content/drive')
# # After you have mounted your Drive and granted necessary permissions, you can read the data within the Drive
#
# df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sample Datasets/titanic/train.csv')
# df.head()
# # 3. GitHub Link
#
# # !git clone <insert GitHuyb repo link 'https://github.com/parameters.git'>
# # 1. Install Python Packages
#
# !pip install pgmpy
# # 2. Check Package Versions
#
# !python --version
# # 2. Check Package Versions
#
# import tensorflow as tf
# print(tf.__version__)
# # Execute system level command with "!"
#
# !ls /bin # List all utilities that are part of /bin
# # Get current directory
#
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# Use a specific version of a library

# %tensorflow_version 2.x
# %tensorflow_version 1.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
# %shell date
# Out:
# Wed 12 Apr 2023 03:36:58 AM UTC

# %%
# How much time it takes to execute a cell

# %time

for i in range(9999):
  for j in range(9999):
    i*j
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 9.06 µs

# %%
# List variables in the environment (this can also be seen with the left hand icon for variables, "{x}")

# %who
# Out:
# df	 drive	 i	 j	 np	 pd	 tf

# %% [markdown]
# 2. Cell Magic Commands.

# %%
# To attach HTML code to cell

# %%html
<h1> Hello World! </h1>
<h2> The quick brown fox jumped over the lazy dog. </h2>
# Out:
# <h1> Hello World! </h1>
# <h2> The quick brown fox jumped over the lazy dog. </h2>

# %%
# Run JavaScript

# %%javascript
console.log('Hello World!')

# %% [markdown]
# # 7. Execute External Python File.

# %%
# Create blank python file

# %%writefile "/content/drive/MyDrive/Colab Notebooks/test.py"
print('Hello World!')
x = 2
print(x)
# Out:
# Overwriting /content/drive/MyDrive/Colab Notebooks/test.py

# %%
# Execute python file

# !python "/content/drive/MyDrive/Colab Notebooks/test.py"
# Out:
# Hello World!
# 2

# %% [markdown]
# # 8. Utilizing GPU, TPU on Google Colab.

# %%
# Check if your Runtime Type is on a GPU

import tensorflow as tf
tf.test.gpu_device_name() # If it returns '', it means you are NOT using a GPU
# Out:
# '/device:GPU:0'

# %% [markdown]
# *Refer to **Section 1. Changing Runtime Type**, on how you can provision GPU / TPU for Google Colab.*

# %% [markdown]
# ### The End.
# ### Thank you!

# %% [markdown]
# **References**
# *   Google Colab Support: https://support.google.com/colab
# *   YouTube Playlist: https://www.youtube.com/playlist?list=PLA83b1JHN4ly56Y7o6vDAT8Szxc3_EdRH
